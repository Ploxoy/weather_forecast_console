# %%
import requests as re
url_template = 'https://wttr.in/{}?nTqmM&lang=ru'
url = url_template.format("Череповец")
response = re.get(url)
response.raise_for_status()
print(response.text)
# Out:
# Череповец
#
#                 Пасмурно
#        .--.     +5(1) °C
#     .-(    ).   ↖ 6 м/c
#    (___.__)__)  10 км
#                 0.0 мм
#                         ┌─────────────┐
# ┌───────────────────────┤ Ср. 29 марта├───────────────────────┐
# │             День      └──────┬──────┘       Ночь            │
# ├──────────────────────────────┼──────────────────────────────┤
# │               Пасмурно       │  _`/"".-.     Местами дождь  │
# │      .--.     +4(0) °C       │   ,\_(   ).   +3(-2) °C      │
# │   .-(    ).   ↖ 5-8 м/c      │    /(___(__)  ↖ 8-12 м/c     │
# │  (___.__)__)  10 км          │      ‘ ‘ ‘ ‘  10 км          │
# │               0.0 мм | 0%    │     ‘ ‘ ‘ ‘   0.1 мм | 77%   │
# └──────────────────────────────┴──────────────────────────────┘
#                         ┌─────────────┐
# ┌───────────────────────┤ Чт. 30 марта├───────────────────────┐
# │             День      └──────┬──────┘       Ночь            │
# ├──────────────────────────────┼──────────────────────────────┤
# │      .-.      Умеренный снег │     \   /     Ясно           │
# │     (   ).    +1(-3) °C      │      .-.      -2(-5) °C      │
# │    (___(__)   ↘ 3-5 м/c      │   ― (   ) ―   ↘ 2-4 м/c      │
# │    * * * *    5 км           │      `-’      10 км          │
# │   * * * *     0.1 мм | 83%   │     /   \     0.0 мм | 0%    │
# └──────────────────────────────┴──────────────────────────────┘
#                         ┌─────────────┐
# ┌───────────────────────┤ Пт. 31 марта├───────────────────────┐
# │             День      └──────┬──────┘       Ночь            │
# ├──────────────────────────────┼──────────────────────────────┤
# │     \   /     Солнечно       │    \  /       Переменная обл…│
# │      .-.      +3(-1) °C      │  _ /"".-.     0(-3) °C       │
# │   ― (   ) ―   ↖ 3-4 м/c      │    \_(   ).   ↖ 3-6 м/c      │
# │      `-’      10 км          │    /(___(__)  10 км          │
# │     /   \     0.0 мм | 0%    │               0.0 мм | 0%    │
# └──────────────────────────────┴──────────────────────────────┘
#
# Все новые фичи публикуются здесь: @igor_chubin

# %%
payload = {'':'nTqmM', 'lang': 'ru'}
url_template = 'https://wttr.in/{}'
url = url_template.format("Череповец")
url
# Out:
# 'https://wttr.in/Череповец'

# %%
response = re.get(url, params=payload)
response.raise_for_status()
print(response.text)
# Out:
# Прогноз погоды: Череповец
#
#                 Пасмурно
#        .--.     +5(1) °C
#     .-(    ).   ↖ 24 км/ч
#    (___.__)__)  10 км
#                 0.0 мм
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤ Ср. 29 марта├───────────────────────┬──────────────────────────────┐
# │             Утро             │             День      └──────┬──────┘      Вечер            │             Ночь             │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │               Пасмурно       │               Пасмурно       │      .-.      Слабая морось  │  _`/"".-.     Местами дождь  │
# │      .--.     +3(-2) °C      │      .--.     +4(0) °C       │     (   ).    +4(-1) °C      │   ,\_(   ).   +3(-2) °C      │
# │   .-(    ).   ← 22-33 км/ч   │   .-(    ).   ↖ 21-31 км/ч   │    (___(__)   ↖ 27-39 км/ч   │    /(___(__)  ↖ 30-45 км/ч   │
# │  (___.__)__)  10 км          │  (___.__)__)  10 км          │     ‘ ‘ ‘ ‘   2 км           │      ‘ ‘ ‘ ‘  10 км          │
# │               0.0 мм | 0%    │               0.0 мм | 0%    │    ‘ ‘ ‘ ‘    0.3 мм | 87%   │     ‘ ‘ ‘ ‘   0.1 мм | 77%   │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤ Чт. 30 марта├───────────────────────┬──────────────────────────────┐
# │             Утро             │             День      └──────┬──────┘      Вечер            │             Ночь             │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │      .-.      Умеренный снег │      .-.      Умеренный снег │    \  /       Переменная обл…│     \   /     Ясно           │
# │     (   ).    0(-4) °C       │     (   ).    +1(-3) °C      │  _ /"".-.     +1(-2) °C      │      .-.      -2(-5) °C      │
# │    (___(__)   ↘ 13-18 км/ч   │    (___(__)   ↘ 14-18 км/ч   │    \_(   ).   ↘ 8-13 км/ч    │   ― (   ) ―   ↘ 8-15 км/ч    │
# │    * * * *    5 км           │    * * * *    5 км           │    /(___(__)  10 км          │      `-’      10 км          │
# │   * * * *     0.2 мм | 0%    │   * * * *     0.1 мм | 83%   │               0.0 мм | 0%    │     /   \     0.0 мм | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤ Пт. 31 марта├───────────────────────┬──────────────────────────────┐
# │             Утро             │             День      └──────┬──────┘      Вечер            │             Ночь             │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │    \  /       Переменная обл…│     \   /     Солнечно       │               Пасмурно       │    \  /       Переменная обл…│
# │  _ /"".-.     +1(-3) °C      │      .-.      +3(-1) °C      │      .--.     +1(-3) °C      │  _ /"".-.     0(-3) °C       │
# │    \_(   ).   ↑ 11-14 км/ч   │   ― (   ) ―   ↖ 14-17 км/ч   │   .-(    ).   ↖ 10-22 км/ч   │    \_(   ).   ↖ 12-25 км/ч   │
# │    /(___(__)  10 км          │      `-’      10 км          │  (___.__)__)  10 км          │    /(___(__)  10 км          │
# │               0.0 мм | 0%    │     /   \     0.0 мм | 0%    │               0.0 мм | 0%    │               0.0 мм | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
# Местоположение: Череповец, городской округ Череповец, Вологодская область, Северо-Западный федеральный округ, 162600, РФ [59.1286965,37.9163892]
#
# Все новые фичи публикуются здесь: @igor_chubin

# %%
response.url
# Out:
# 'https://wttr.in/%D0%A7%D0%B5%D1%80%D0%B5%D0%BF%D0%BE%D0%B2%D0%B5%D1%86?=nTqmM&lang=ru'

# %%
params={'n':None,
        'T':None,
        'q':None,
        'm':None,
        'M':None,
        'lang':'ru'}
# так как ключи с нулевым параметром не передаются в requests преобразуем в строку        
#params = '&'.join([k if v is None else f"{k}={v}" for k, v in params.items()])
#params
# Out:
# 'n&T&q&m&M&lang=ru'

# %%
import requests
url_template = 'https://wttr.in/{}'
params = {'n': None,  # narrow version (only day and night)
          'T': None,  # switch terminal sequences off (no colors)
          'q': None,  # quiet version (no "Weather report" text)
          'm': None,  # metric (SI) (used by default everywhere except US)
          'M': None,  # show wind speed in m/s
          'lang': 'ru'}
# так как ключи с нулевым параметром не передаются в requests, преобразуем словарь  в строку:
params = '&'.join([k if v is None else f"{k}={v}" for k, v in params.items()])
cityes = ['Лондон', 'Шереметьево', 'Череповец']
for city in cityes:
    url = url_template.format(city)
    response = requests.get(url, params=params)
    response.raise_for_status()
    print(response.text)
# Out:
# Лондон
#
#      \  /       Переменная облачность
#    _ /"".-.     +13(11) °C
#      \_(   ).   ↗ 6 м/c
#      /(___(__)  10 км
#                 0.2 мм
#                         ┌─────────────┐
# ┌───────────────────────┤ Ср. 29 марта├───────────────────────┐
# │             День      └──────┬──────┘       Ночь            │
# ├──────────────────────────────┼──────────────────────────────┤
# │      .-.      Слабая морось  │      .-.      Небольшой дожд…│
# │     (   ).    +13(11) °C     │     (   ).    +13(10) °C     │
# │    (___(__)   ↑ 5-7 м/c      │    (___(__)   ↑ 8-12 м/c     │
# │     ‘ ‘ ‘ ‘   2 км           │     ‘ ‘ ‘ ‘   9 км           │
# │    ‘ ‘ ‘ ‘    0.7 мм | 81%   │    ‘ ‘ ‘ ‘    1.4 мм | 86%   │
# └──────────────────────────────┴──────────────────────────────┘
#                         ┌─────────────┐
# ┌───────────────────────┤ Чт. 30 марта├───────────────────────┐
# │             День      └──────┬──────┘       Ночь            │
# ├──────────────────────────────┼──────────────────────────────┤
# │               Пасмурно       │               Пасмурно       │
# │      .--.     +12(10) °C     │      .--.     +10(8) °C      │
# │   .-(    ).   ↗ 5-6 м/c      │   .-(    ).   ↑ 4-6 м/c      │
# │  (___.__)__)  10 км          │  (___.__)__)  10 км          │
# │               0.0 мм | 0%    │               0.0 мм | 0%    │
# └──────────────────────────────┴──────────────────────────────┘
#                         ┌─────────────┐
# ┌───────────────────────┤ Пт. 31 марта├───────────────────────┐
# │             День      └──────┬──────┘       Ночь            │
# ├──────────────────────────────┼──────────────────────────────┤
# │               Пасмурно       │      .-.      Слабая морось  │
# │      .--.     +12(9) °C      │     (   ).    +10(7) °C      │
# │   .-(    ).   ↗ 8-10 м/c     │    (___(__)   → 6-8 м/c      │
# │  (___.__)__)  10 км          │     ‘ ‘ ‘ ‘   2 км           │
# │               0.0 мм | 0%    │    ‘ ‘ ‘ ‘    0.6 мм | 70%   │
# └──────────────────────────────┴──────────────────────────────┘
#
# Все новые фичи публикуются здесь: @igor_chubin
#
# Шереметьево
#
#                 Облачно
#        .--.     +7(5) °C
#     .-(    ).   ↑ 4 м/c
#    (___.__)__)  10 км
#                 0.0 мм
#                         ┌─────────────┐
# ┌───────────────────────┤ Ср. 29 марта├───────────────────────┐
# │             День      └──────┬──────┘       Ночь            │
# ├──────────────────────────────┼──────────────────────────────┤
# │  _`/"".-.     Местами дождь  │               Пасмурно       │
# │   ,\_(   ).   +8(5) °C       │      .--.     +5(2) °C       │
# │    /(___(__)  ↑ 5-6 м/c      │   .-(    ).   → 3-4 м/c      │
# │      ‘ ‘ ‘ ‘  10 км          │  (___.__)__)  10 км          │
# │     ‘ ‘ ‘ ‘   0.1 мм | 67%   │               0.0 мм | 0%    │
# └──────────────────────────────┴──────────────────────────────┘
#                         ┌─────────────┐
# ┌───────────────────────┤ Чт. 30 марта├───────────────────────┐
# │             День      └──────┬──────┘       Ночь            │
# ├──────────────────────────────┼──────────────────────────────┤
# │               Пасмурно       │               Пасмурно       │
# │      .--.     +5(2) °C       │      .--.     +4(-1) °C      │
# │   .-(    ).   ↘ 4-5 м/c      │   .-(    ).   ↘ 5-8 м/c      │
# │  (___.__)__)  10 км          │  (___.__)__)  10 км          │
# │               0.0 мм | 0%    │               0.0 мм | 0%    │
# └──────────────────────────────┴──────────────────────────────┘
#                         ┌─────────────┐
# ┌───────────────────────┤ Пт. 31 марта├───────────────────────┐
# │             День      └──────┬──────┘       Ночь            │
# ├──────────────────────────────┼──────────────────────────────┤
# │      .-.      Небольшой дожд…│      .-.      Умеренный дожд…│
# │     (   ).    +3(-2) °C      │     (   ).    +3(0) °C       │
# │    (___(__)   ↘ 6-7 м/c      │    (___(__)   ↘ 3-5 м/c      │
# │     ‘ ‘ ‘ ‘   9 км           │   ‚‘‚‘‚‘‚‘    7 км           │
# │    ‘ ‘ ‘ ‘    1.9 мм | 73%   │   ‚’‚’‚’‚’    6.9 мм | 77%   │
# └──────────────────────────────┴──────────────────────────────┘
#
# Все новые фичи публикуются здесь: @igor_chubin
#
# Череповец
#
#    _`/"".-.     Местами дождь
#     ,\_(   ).   +4(-1) °C
#      /(___(__)  ↖ 6 м/c
#        ‘ ‘ ‘ ‘  10 км
#       ‘ ‘ ‘ ‘   0.1 мм
#                         ┌─────────────┐
# ┌───────────────────────┤ Ср. 29 марта├───────────────────────┐
# │             День      └──────┬──────┘       Ночь            │
# ├──────────────────────────────┼──────────────────────────────┤
# │               Пасмурно       │      .-.      Небольшой дожд…│
# │      .--.     +4(0) °C       │     (   ).    +3(-3) °C      │
# │   .-(    ).   ↖ 5-8 м/c      │    (___(__)   ↖ 7-11 м/c     │
# │  (___.__)__)  10 км          │     ‘ ‘ ‘ ‘   9 км           │
# │               0.0 мм | 0%    │    ‘ ‘ ‘ ‘    0.8 мм | 72%   │
# └──────────────────────────────┴──────────────────────────────┘
#                         ┌─────────────┐
# ┌───────────────────────┤ Чт. 30 марта├───────────────────────┐
# │             День      └──────┬──────┘       Ночь            │
# ├──────────────────────────────┼──────────────────────────────┤
# │      .-.      Умеренный снег │     \   /     Ясно           │
# │     (   ).    +1(-3) °C      │      .-.      -2(-5) °C      │
# │    (___(__)   ↘ 3-4 м/c      │   ― (   ) ―   ↘ 2-3 м/c      │
# │    * * * *    5 км           │      `-’      10 км          │
# │   * * * *     0.1 мм | 0%    │     /   \     0.0 мм | 0%    │
# └──────────────────────────────┴──────────────────────────────┘
#                         ┌─────────────┐
# ┌───────────────────────┤ Пт. 31 марта├───────────────────────┐
# │             День      └──────┬──────┘       Ночь            │
# ├──────────────────────────────┼──────────────────────────────┤
# │     \   /     Солнечно       │               Облачно        │
# │      .-.      +3(0) °C       │      .--.     0(-3) °C       │
# │   ― (   ) ―   ↑ 2-3 м/c      │   .-(    ).   ↖ 2-4 м/c      │
# │      `-’      10 км          │  (___.__)__)  10 км          │
# │     /   \     0.0 мм | 0%    │               0.0 мм | 0%    │
# └──────────────────────────────┴──────────────────────────────┘
#
# Все новые фичи публикуются здесь: @igor_chubin
